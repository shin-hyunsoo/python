# %% [markdown]
# # 발전소의 전기 에너지 발전량 예측
# > 원본 데이터 다운로드 경로 : https://archive.ics.uci.edu/ml/datasets/Combined+Cycle+Power+Plant
#
# - 발전소의 시간당 순수 전기 에너지 출력(PE)을 예측하기 위해 시간당 평균 주변 변수 온도(AT), 주변 압력(AP), 상대 습도(RH) 및 배기 진공(V)으로 구성

# %%
# 데이터 분석을 위한 모듈 import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Folds5x2_pp.xlsx 파일을 읽어 df에 저장하세요.

# %%
# 상위 5개를 출력
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
# 컬럼별 결측치가 존재하는지 확인
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
# 데이터 프레임의 정보 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
# AT    9568 non-null float64
# V     9568 non-null float64
# AP    9568 non-null float64
# RH    9568 non-null float64
# PE    9568 non-null float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# 열별 기술통계분석 적용
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
# Y 데이터인 PE 컬럼의 값 범위를 확인하기 위해 boxplot으로 그려보세요.

# %%
# 나머지 컬럼도 boxplot으로 시각화 해보세요.

# %%
# seaborn의 distplot을 이용하여 PE 컬럼의 분포를 확인해보세요.
# Out:
# Text(0.5, 1.0, 'PE')

# %%
# 나머지 컬럼도 distplot으로 시각화 해보세요.

# %%
# 데이터 프레임의 corr()을 이용하여 변수 별 상관 관계를 구하세요.
# Out:
#           AT         V        AP        RH        PE
# AT  1.000000  0.844107 -0.507549 -0.542535 -0.948128
# V   0.844107  1.000000 -0.413502 -0.312187 -0.869780
# AP -0.507549 -0.413502  1.000000  0.099574  0.518429
# RH -0.542535 -0.312187  0.099574  1.000000  0.389794
# PE -0.948128 -0.869780  0.518429  0.389794  1.000000

# %%
# seaborn의 heatmap을 이용하여 상관 관계를 시각화 하세요.|

# %%
# seaborn의 pairplot을 이용하여 컬럼간 관계를 시각화

# %%
# 학습 및 테스트 데이터 분할을 위해 AT컬럼부터 RH컬럼을 X로 PE 컬럼을 Y로 분할

# %%
# 학습 및 테스트 데이터 분할
from sklearn.model_selection import train_test_split

# %%
# LinearRegression 모델 생성 및 학습
# Out:
# (0.9277203285742034, 0.9314814915353968)

# %%
#  Folds5x2_pp.xlsx 파일에서 교차 검증을 위한 다른 df로 불러와 테스트 진행
sheet2

# %%
# Out:
# 0.9286894216195787

# %%
#  Folds5x2_pp.xlsx 파일에서 교차 검증을 위한 다른 df로 불러와 테스트 진행
sheet3

# %%
# Out:
# 0.9286894216195787

# %%
#  Folds5x2_pp.xlsx 파일에서 교차 검증을 위한 다른 df로 불러와 테스트 진행
sheet4

# %%
# Out:
# 0.9286894216195787

# %%
#  Folds5x2_pp.xlsx 파일에서 교차 검증을 위한 다른 df로 불러와 테스트 진행
sheet5

# %%
# Out:
# 0.9286894216195787
